# %%
from selenium import webdriver
import chromedriver_binary

# %%
# webdriver.Chrome()

# %%
chromedriver_binary.chromedriver_filename
# Out:
# '/home/robotx/Desktop/robotx/webscrape/.scrape_ven/lib/python3.13/site-packages/chromedriver_binary/chromedriver'

# %%
driver = webdriver.Chrome()
