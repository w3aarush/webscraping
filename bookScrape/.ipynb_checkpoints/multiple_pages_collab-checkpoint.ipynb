# %%
import pandas as pd
import requests
from tqdm import tqdm
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('/content/book_data_multiple_pages.csv')

# %%
df.head()
# Out:
#                                    title rating   price     stock  \
# 0                   A Light in the Attic  Three  £51.77  In stock
# 1                     Tipping the Velvet    One  £53.74  In stock
# 2                             Soumission    One  £50.10  In stock
# 3                          Sharp Objects   Four  £47.82  In stock
# 4  Sapiens: A Brief History of Humankind   Five  £54.23  In stock
#
#                                            book_link  \
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#
#                                           image_link
# 0  https://books.toscrape.com//media/cache/2c/da/...
# 1  https://books.toscrape.com//media/cache/26/0c/...
# 2  https://books.toscrape.com//media/cache/3e/ef/...
# 3  https://books.toscrape.com//media/cache/32/51/...
# 4  https://books.toscrape.com//media/cache/be/a5/...

# %%
df.book_link.head()
# Out:
# 0    https://books.toscrape.com/catalogue/a-light-i...
# 1    https://books.toscrape.com/catalogue/tipping-t...
# 2    https://books.toscrape.com/catalogue/soumissio...
# 3    https://books.toscrape.com/catalogue/sharp-obj...
# 4    https://books.toscrape.com/catalogue/sapiens-a...
# Name: book_link, dtype: object

# %%
data = []

for link in tqdm(df['book_link']):
    res     = requests.get(link)
    soup    = BeautifulSoup(res.text, 'html.parser')

    '''
    typ     = soup.find('ul', class_='breadcrumb').find_all('a')[-1].text
    upc     = soup.find('table', class_ = 'table table-striped').find_all('td')[0].text
    price_x = soup.find('table', class_ = 'table table-striped').find_all('td')[2].text[2:]
    price_i = soup.find('table', class_ = 'table table-striped').find_all('td')[3].text[2:]
    tax     = soup.find('table', class_ = 'table table-striped').find_all('td')[4].text[2:]
    qn   = soup.find('table', class_ = 'table table-striped').find_all('td')[5].text
    reviews = soup.find('table', class_ = 'table table-striped').find_all('td')[6].text
    description = soup.find('article', class_ = 'product_page').find_all('p')[-1].text
    '''
    typ   = soup.find('ul', class_='breadcrumb').find_all('a')[-1].text
    temp  = soup.find('table', class_ = 'table table-striped').find_all('td')

    upc   = temp[0].text
    price_x = temp[2].text[2:]
    price_i = temp[3].text[2:]
    tax     = temp[4].text[2:]
    qn      = temp[5].text
    reviews = temp[6].text
    description = soup.find('article', class_ = 'product_page').find_all('p')[-1].text

    data.append([typ,upc,price_x,price_i,tax,qn,reviews,description])
# Out:
#   0%|                                                                      | 0/1000 [00:01<?, ?it/s]
# https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html

# %%
data[0]
# Out:
# ['Poetry',
#  'a897fe39b1053632',
#  '51.77',
#  '51.77',
#  '0.00',
#  'In stock (22 available)',
#  '0',
#  "It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never sounded so good. ...more"]

# %%
df2 = pd.DataFrame(data, columns=['typ', 'upc', 'price_x', 'price_i', 'tax', 'qn', 'reviews', 'description'])

# %%
df2.head()
# Out:
#                   typ               upc price_x price_i   tax  \
# 0              Poetry  a897fe39b1053632   51.77   51.77  0.00
# 1  Historical Fiction  90fa61229261140a   53.74   53.74  0.00
# 2             Fiction  6957f44c3847a760   50.10   50.10  0.00
# 3             Mystery  e00eb4fd7b871a48   47.82   47.82  0.00
# 4             History  4165285e1663650f   54.23   54.23  0.00
#
#                         qn reviews  \
# 0  In stock (22 available)       0
# 1  In stock (20 available)       0
# 2  In stock (20 available)       0
# 3  In stock (20 available)       0
# 4  In stock (20 available)       0
#
#                                          description
# 0  It's hard to imagine a world without A Light i...
# 1                 \n\n    \n        In stock\n    \n
# 2                 \n\n    \n        In stock\n    \n
# 3                 \n\n    \n        In stock\n    \n
# 4                 \n\n    \n        In stock\n    \n

# %%
df2.to_csv('book_data_final.csv', index=False)

# %%
df3 = pd.concat([df, df2], axis=1)

# %%
df3.head()
# Out:
#                                    title rating   price     stock  \
# 0                   A Light in the Attic  Three  £51.77  In stock
# 1                     Tipping the Velvet    One  £53.74  In stock
# 2                             Soumission    One  £50.10  In stock
# 3                          Sharp Objects   Four  £47.82  In stock
# 4  Sapiens: A Brief History of Humankind   Five  £54.23  In stock
#
#                                            book_link  \
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#
#                                           image_link                 typ  \
# 0  https://books.toscrape.com//media/cache/2c/da/...              Poetry
# 1  https://books.toscrape.com//media/cache/26/0c/...  Historical Fiction
# 2  https://books.toscrape.com//media/cache/3e/ef/...             Fiction
# 3  https://books.toscrape.com//media/cache/32/51/...             Mystery
# 4  https://books.toscrape.com//media/cache/be/a5/...             History
#
#                 upc price_x price_i   tax                       qn reviews  \
# 0  a897fe39b1053632   51.77   51.77  0.00  In stock (22 available)       0
# 1  90fa61229261140a   53.74   53.74  0.00  In stock (20 available)       0
# 2  6957f44c3847a760   50.10   50.10  0.00  In stock (20 available)       0
# 3  e00eb4fd7b871a48   47.82   47.82  0.00  In stock (20 available)       0
# 4  4165285e1663650f   54.23   54.23  0.00  In stock (20 available)       0
#
#                                          description
# 0  It's hard to imagine a world without A Light i...
# 1                 \n\n    \n        In stock\n    \n
# 2                 \n\n    \n        In stock\n    \n
# 3                 \n\n    \n        In stock\n    \n
# 4                 \n\n    \n        In stock\n    \n
